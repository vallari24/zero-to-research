# %% [markdown]
# # Lecture Template
#
# Use one notebook per lecture. Keep the reproduction separate from your
# original extension.
#
# ## Fill in before you start
# - Lecture:
# - Date:
# - Source:
# - Goal:
# - Original delta:

# %%
from pathlib import Path
import random

import matplotlib.pyplot as plt
import numpy as np

try:
    import torch
    TORCH_AVAILABLE = True
except ImportError:
    torch = None
    TORCH_AVAILABLE = False

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
if TORCH_AVAILABLE:
    torch.manual_seed(SEED)

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "notebooks").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent

print(f"torch available: {TORCH_AVAILABLE}")
PROJECT_ROOT

# %% [markdown]
# ## 1. Reproduce the lecture
#
# Write the smallest faithful implementation first.
#
# ## 2. Add one original delta
#
# Change exactly one thing:
# - dataset
# - initialization
# - width or depth
# - learning rate schedule
# - visualization or diagnostics
# - evaluation metric
#
# ## 3. Record outcomes
#
# End every notebook with:
# - what matched the lecture
# - what changed
# - one surprising result
# - one next question

# %%
# Start here
