# %% [markdown]
# <a href="https://colab.research.google.com/github/vallari24/zero-to-research/blob/main/notebooks/07_tinystories_gpt_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # TinyStories GPT Setup
#
# TinyStories setup for building GPT from scratch.

# %%
# We always start with a dataset to train on. Let's download the TinyStories toy dataset
# !wget -O input.txt https://raw.githubusercontent.com/vallari24/zero-to-research/main/data/tiny-input.txt

# %%
# read it in to inspect it
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# %%
print("length of dataset in characters: ", len(text))

# %%
# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
print(''.join(chars))
print(vocab_size)
